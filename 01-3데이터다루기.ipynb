# %%
#구글 드라이브에서 파일 불러오기
import gdown
gdown.download('https://drive.google.com/uc?id=1Y0IeakjUU9nHy1QIIgekql6PNepzAT4-','남산도서관 장서 대출목록(2026년 06월).csv',quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Y0IeakjUU9nHy1QIIgekql6PNepzAT4-
# To: /content/남산도서관 장서 대출목록(2026년 06월).csv
# 100%|██████████| 78.0M/78.0M [00:00<00:00, 89.7MB/s]
# '남산도서관 장서 대출목록(2026년 06월).csv'

# %%
#파일에서 한 줄 읽어서 출력하기
with open('남산도서관 장서 대출목록(2026년 06월).csv') as f:
  print(f.readline())
# Out:
# ﻿번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,

# %%
#파일 인코딩 형식 확인 chardet.detect()함수
import chardet
with open('남산도서관 장서 대출목록(2026년 06월).csv',mode='rb')as f: #'rb' 바이너리 모드로 지정
  d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
import pandas as pd
df = pd.read_csv('남산도서관 장서 대출목록(2026년 06월).csv') #파일 안에 있는 데이터 타입이 달라 경고가 발생함
# Out:
# /tmp/ipykernel_533/3924764418.py:2: DtypeWarning: Columns (5,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('남산도서관 장서 대출목록(2026년 06월).csv')

# %%
import pandas as pd
df = pd.read_csv('남산도서관 장서 대출목록(2026년 06월).csv', low_memory=False)
df.head()
# Out:
#    번호                     도서명                  저자   출판사  발행년도           ISBN  \
# 0   1  지도와 전쟁으로 다시 읽는 한중일 세계사              이동민 지음  갈매나무  2026  9791124226087
# 1   2                      흉담              전건우 지음   래빗홀  2026  9791168343764
# 2   3          아름다움이 사람을 죽일 때  미시마 유키오 지음, 심지애 옮김   북로드  2026  9791158792541
# 3   4                파이로매니악 1              이우혁 지음    반타  2026  9791175772656
# 4   5                파이로매니악 2              이우혁 지음    반타  2026  9791175772663
#
#    세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0      NaN  NaN  NaN    NaN     1     0  2026-04-30          NaN
# 1      NaN  NaN  NaN    NaN     1     0  2026-04-30          NaN
# 2      NaN  NaN  NaN    NaN     1     0  2026-04-30          NaN
# 3      NaN  NaN  NaN    NaN     1     0  2026-04-30          NaN
# 4      NaN  NaN  NaN    NaN     1     0  2026-04-30          NaN

# %%
#엑셀로 저장(xlsxwriter 패키지 설치 후 to_excel() 메서드에 engine='xlsxwriter' 지정)
# !pip install xlsxwriter
df.to_excel('남산도서관 장서 대출목록(2026년 06월).xlsx',engine='xlsxwriter')
